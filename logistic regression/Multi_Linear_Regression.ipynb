# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings("ignore")

# %%
#from google.colab import files
#uploaded=files.upload()

# %%
#Read the data
cars = pd.read_csv("/content/Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %% [markdown]
# - HP - Horsepower of the car
# - MPG - Miles Per Gallon (Mileage)
# - VOL - Cubic Feet Space in the Car
# - SP - Top Speed of the Car
# - WT - Weight of the car in thousand pounds
#
# We need to make predictions on the MPG, using the other independent variables.

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
#check for missing values
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %% [markdown]
# # Correlation Matrix
#
# -1 ---------- -0.5 ---------- 0 ---------- +0.5 ---------- +1

# %%
sns.heatmap(cars.corr(), annot=True, fmt='.4g')
# Out:
# <Axes: >

# %% [markdown]
# We can see that Horsepower & Top speed are highly correlated variables, followed by Horsepower & MPG, & Top speed & miles per gallon.
# Volume & weight of the car also show a very high correlation,
# & all the above correlations are also logically true.

# %% [markdown]
# # Scatterplot between variables along with histograms

# %%
#Format the plot background and scatter plots for all the variables
sns.set_style(style='darkgrid')
sns.pairplot(cars)

# %% [markdown]
# # Preparing a model

# %%
#Build model
#import statsmodels.formula.api as smf
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()

# %%
from pickle import BININT1
#Beta Coefficients
model.params

#Y = B0 + B1X1 + B2X2 + B3X3 + B4X4
#Where B1,B2,B3,B4 are the slopes of the IVs
# Out:
# Intercept    30.677336
# WT            0.400574
# VOL          -0.336051
# SP            0.395627
# HP           -0.205444
# dtype: float64

# %% [markdown]
# |Variable|Slope|Impact on Dependent Variable|Result Interpretation|
# |--------|-----|----------------------------|---------------------|
# |Intercept|30.677336 (B0)|NA|NA|
# |WT (X1)|0.400574 (B1)|Will increase DV|With a unit increase in WT, we shall see 0.400574 unit increase in the MPG|
# |VOL (X2)|-0.336051 (B2)|Will decrease DV|With a unit increase in VOL, we shall see 0.336051 unit decrease in the MPG|
# |SP (X3)|0.395627 (B3)|Will increase DV|With a unit increase in SP, we shall see 0.395627 unit increase in the MPG|
# |HP (X4)|-0.205444 (B4)|Will decrease DV|With a unit increase in HP, we shall see 0.205444 unit decrease in the MPG|

# %% [markdown]
# # Interpreting the Beta Coefficients
#
# - With a unit increase in WT, we shall see 0.400574 unit increase in the MPG
# - With a unit increase in VOL, we shall see 0.336051 unit decrease in the MPG
# - With a unit increase in SP, we shall see 0.395627 unit increase in the MPG
# - With a unit increase in HP, we shall see 0.205444 unit decrease in the MPG

# %%
#Predicted Values for MPG
model.fittedvalues
# Out:
# 0     43.441935
# 1     42.388793
# 2     42.279341
# 3     42.538360
# 4     42.172648
#         ...
# 76    21.282096
# 77    17.899050
# 78    26.136453
# 79    12.316612
# 80    15.559481
# Length: 81, dtype: float64

# %% [markdown]
# |Variable|Slope|
# |--------|-----|
# |Intercept|30.677336 (B0)|
# |WT (X1)|0.400574 (B1)|
# |VOL (X2)|-0.336051 (B2)|
# |SP (X3)|0.395627 (B3)|
# |HP (X4)|-0.205444 (B4)|

# %%
#Y = B0 + B1*X1 + B2*X2 + B3*X3 + B4*X4
cars['Predictions_Manual']=30.677336+0.400574*cars['WT']-0.336051*cars['VOL']+0.395627*cars['SP']-0.205444*cars['HP']
cars['Predictions_Model']=model.fittedvalues
cars['Errors_Manual']=cars['MPG']-cars['Predictions_Manual']
cars['Errors_Model']=model.resid
cars['Y']=30.677336+0.400574*cars['WT']-0.336051*cars['VOL']+0.395627*cars['SP']-0.205444*cars['HP'] + cars['Errors_Model']
cars
# Out:
#      HP        MPG  VOL          SP         WT  Predictions_Manual  \
# 0    49  53.700681   89  104.185353  28.762059           43.441913
# 1    55  50.013401   92  105.461264  30.466833           42.388768
# 2    55  50.013401   92  105.461264  30.193597           42.279317
# 3    70  45.696322   92  113.461264  30.632114           42.538332
# 4    53  50.504232   92  104.461264  29.889149           42.172624
# ..  ...        ...  ...         ...        ...                 ...
# 76  322  36.900000   50  169.598513  16.132947           21.282008
# 77  238  19.197888  115  150.576579  37.923113           17.898973
# 78  263  34.000000   50  151.598513  15.769625           26.136381
# 79  295  19.833733  119  167.944460  39.423099           12.316518
# 80  236  12.101263  107  139.840817  34.948615           15.559404
#
#     Predictions_Model  Errors_Manual  Errors_Model          Y
# 0           43.441935      10.258769     10.258747  53.700659
# 1           42.388793       7.624633      7.624608  50.013377
# 2           42.279341       7.734084      7.734060  50.013377
# 3           42.538360       3.157991      3.157963  45.696294
# 4           42.172648       8.331608      8.331584  50.504208
# ..                ...            ...           ...        ...
# 76          21.282096      15.617992     15.617904  36.899912
# 77          17.899050       1.298915      1.298838  19.197810
# 78          26.136453       7.863619      7.863547  33.999928
# 79          12.316612       7.517215      7.517122  19.833640
# 80          15.559481      -3.458142     -3.458218  12.101187
#
# [81 rows x 10 columns]

# %%
cars['Error_Squared']= cars['Errors_Model']**2
cars
# Out:
#      HP        MPG  VOL          SP         WT  Predictions_Manual  \
# 0    49  53.700681   89  104.185353  28.762059           43.441913
# 1    55  50.013401   92  105.461264  30.466833           42.388768
# 2    55  50.013401   92  105.461264  30.193597           42.279317
# 3    70  45.696322   92  113.461264  30.632114           42.538332
# 4    53  50.504232   92  104.461264  29.889149           42.172624
# ..  ...        ...  ...         ...        ...                 ...
# 76  322  36.900000   50  169.598513  16.132947           21.282008
# 77  238  19.197888  115  150.576579  37.923113           17.898973
# 78  263  34.000000   50  151.598513  15.769625           26.136381
# 79  295  19.833733  119  167.944460  39.423099           12.316518
# 80  236  12.101263  107  139.840817  34.948615           15.559404
#
#     Predictions_Model  Errors_Manual  Errors_Model          Y  Error_Squared
# 0           43.441935      10.258769     10.258747  53.700659     105.241882
# 1           42.388793       7.624633      7.624608  50.013377      58.134651
# 2           42.279341       7.734084      7.734060  50.013377      59.815679
# 3           42.538360       3.157991      3.157963  45.696294       9.972728
# 4           42.172648       8.331608      8.331584  50.504208      69.415289
# ..                ...            ...           ...        ...            ...
# 76          21.282096      15.617992     15.617904  36.899912     243.918926
# 77          17.899050       1.298915      1.298838  19.197810       1.686979
# 78          26.136453       7.863619      7.863547  33.999928      61.835369
# 79          12.316612       7.517215      7.517122  19.833640      56.507118
# 80          15.559481      -3.458142     -3.458218  12.101187      11.959270
#
# [81 rows x 11 columns]

# %%
Mean_Squared_Error= cars['Error_Squared'].mean()
Mean_Squared_Error
# Out:
# 18.89714115234311

# %%
model.mse_resid
# Out:
# 20.140374122892

# %%
model.mse_model
# Out:
# 1284.998549461944

# %% [markdown]
# # Beta Coefficient Interpretation
#
# - Given a unit increase in the WT variable, the MPG variable will increase by 0.400574 since it is a positive Beta Coefficient for WT variable.
#
# - Given a unit increase in the VOL variable, the MPG variable will decrease by 0.336051 since it is a negative Beta Coefficient for VOL variable.
#
# - Given a unit increase in the SP variable, the MPG variable will increase by 0.395627 since it is a positive Beta Coefficient for SP variable.
#
# - Given a unit increase in the HP variable, the MPG variable will decrease by 0.205444 since it is a negative Beta Coefficient for HP variable.

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)

# %% [markdown]
# ### Null Hypothesis - The independent variable is not at all significantly related to the dependent variable
#
# ### Alternate Hypothesis - The independent variable is significantly related to the dependent variable
#
# For any variable, if p-value<0.05, then we can consider that variable to be useful/significant to predict the dependent variable.

# %%
model.pvalues
# Out:
# Intercept    0.042936
# WT           0.813649
# VOL          0.556294
# SP           0.014579
# HP           0.000001
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.7705372737359842, 0.7584602881431413)

# %%
# WT & VOL are highly correlated
# Try to run the model with only WT, SP & HP, excluding VOL. Check for Mean Squared Error.
# Try to run the model with only VOL, SP & HP, excluding WT. Check for Mean Squared Error.
# The model which gives lesser Mean Squared Error can be accepted.

# %% [markdown]
# # To check which of the correlated variables should we drop from the model, we will run the following models & check for their MSE values.

# %%
#model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()
model = smf.ols('MPG~WT+SP',data=cars).fit()
model.mse_resid
# Out:
# 27.14248826815853

# %%
model = smf.ols('MPG~WT+HP',data=cars).fit()
model.mse_resid
# Out:
# 21.457526704357836

# %%
model = smf.ols('MPG~VOL+HP',data=cars).fit()
model.mse_resid
# Out:
# 21.323831192747125

# %%
model = smf.ols('MPG~VOL+SP',data=cars).fit()
model.mse_resid
# Out:
# 26.947136191181674

# %% [markdown]
# # Simple Linear Regression Models

# %%
ml_v=smf.ols('MPG~VOL',data = cars).fit()
#t and p-Values
#print(ml_v.tvalues, '\n', ml_v.pvalues)
ml_v.mse_resid
# Out:
# 60.80428341577306

# %%
ml_w=smf.ols('MPG~WT',data = cars).fit()
#print(ml_w.tvalues, '\n', ml_w.pvalues)
ml_w.mse_resid
# Out:
# 61.00910874510843

# %%
ml_hp=smf.ols('MPG~HP',data = cars).fit()
#print(ml_w.tvalues, '\n', ml_w.pvalues)
ml_hp.mse_resid
# Out:
# 40.05094480090485

# %%
ml_sp=smf.ols('MPG~SP',data = cars).fit()
#print(ml_w.tvalues, '\n', ml_w.pvalues)
ml_sp.mse_resid
# Out:
# 44.571828094579864

# %%
ml_hp_vol=smf.ols('MPG~HP+VOL',data = cars).fit()
print(ml_hp_vol.pvalues)
ml_hp_vol.mse_resid
# Out:
# Intercept    7.697003e-41
# HP           1.203680e-19
# VOL          1.654693e-12
# dtype: float64
# 21.32383119274713

# %% [markdown]
# # Calculating VIF (Variance Inflation Factor)

# %%
#The variable for which we are calculating the VIF value, must be the DV, while other IVs will remain as IVs in the ols function.
#After running the function, calculate (1/(1 - r-squared))

rsq_hp = smf.ols('HP~WT+VOL+SP',data=cars).fit().rsquared
vif_hp = 1/(1-rsq_hp)

rsq_wt = smf.ols('WT~HP+VOL+SP',data=cars).fit().rsquared
vif_wt = 1/(1-rsq_wt)

rsq_vol = smf.ols('VOL~WT+SP+HP',data=cars).fit().rsquared
vif_vol = 1/(1-rsq_vol)

rsq_sp = smf.ols('SP~WT+VOL+HP',data=cars).fit().rsquared
vif_sp = 1/(1-rsq_sp)

# Storing vif values in a data frame
d1 = {'Variables':['HP','WT','VOL','SP'],'VIF':[vif_hp,vif_wt,vif_vol,vif_sp]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#   Variables         VIF
# 0        HP   19.926589
# 1        WT  639.533818
# 2       VOL  638.806084
# 3        SP   20.007639

# %% [markdown]
# - Try a model with HP & WT. Check for MSE (Mean Squared Error)
# - Try a model with HP & VOL. Check for MSE (Mean Squared Error)
# - Try a model with SP & WT. Check for MSE (Mean Squared Error)
# - Try a model with SP & VOL. Check for MSE (Mean Squared Error)
#
# The model with the least MSE can be accepted.

# %%
model = smf.ols('MPG~WT+HP',data=cars).fit()
model.mse_resid
# Out:
# 21.457526704357836

# %%
model = smf.ols('MPG~WT+SP',data=cars).fit()
model.mse_resid
# Out:
# 27.14248826815853

# %%
model = smf.ols('MPG~VOL+HP',data=cars).fit()
model.mse_resid
# Out:
# 21.323831192747125

# %%
model = smf.ols('MPG~VOL+SP',data=cars).fit()
model.mse_resid
# Out:
# 26.947136191181674

# %% [markdown]
# # Residual Analysis

# %%
model = smf.ols('MPG~VOL+HP',data=cars).fit()
model.mse_resid
# Out:
# 21.323831192747125

# %% [markdown]
# ## Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagonal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
ml_hp_vol=smf.ols('MPG~HP+VOL',data = cars).fit()
data_hp_vol = cars.loc[:,['HP','VOL','MPG']]
data_hp_vol['Predictions'] = ml_hp_vol.fittedvalues
data_hp_vol['Errors']= ml_hp_vol.resid
data_hp_vol
# Out:
#      HP  VOL        MPG  Predictions     Errors
# 0    49   89  53.700681    43.857952   9.842729
# 1    55   92  50.013401    42.613384   7.400017
# 2    55   92  50.013401    42.613384   7.400017
# 3    70   92  45.696322    40.962949   4.733373
# 4    53   92  50.504232    42.833442   7.670790
# ..  ...  ...        ...          ...        ...
# 76  322   50  36.900000    21.417152  15.482848
# 77  238  115  19.197888    17.997726   1.200162
# 78  263   50  34.000000    27.908863   6.091137
# 79  295  119  19.833733    10.946881   8.886852
# 80  236  107  12.101263    19.776167  -7.674904
#
# [81 rows x 5 columns]

# %%
sns.boxplot(ml_hp_vol.resid)
# Out:
# <Axes: >

# %%
sns.histplot(ml_hp_vol.resid)
# Out:
# <Axes: ylabel='Count'>

# %%
model = smf.ols('MPG~VOL+HP',data=cars).fit()

def get_standardized_values(vals):
    return (vals - vals.mean())/vals.std()
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
model = smf.ols('MPG~VOL+HP',data=cars).fit()

def get_standardized_values(vals):
    return (vals - vals.mean())/vals.std()

plt.scatter(get_standardized_values(cars['HP']),get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized IV values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
def get_standardized_values(vals):
    return (vals - vals.mean())/vals.std()
plt.scatter(get_standardized_values(cars['VOL']),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized IV values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Types of transformations
# - Log transformation
# - Square transformation
# - Square root transformation
# - Cube transformation
# - Cube root transformation

# %%
cars['SQRT_HP']=np.sqrt(cars['HP'])
cars
# Out:
#      HP        MPG  VOL          SP         WT  Predictions_Manual  \
# 0    49  53.700681   89  104.185353  28.762059           43.441913
# 1    55  50.013401   92  105.461264  30.466833           42.388768
# 2    55  50.013401   92  105.461264  30.193597           42.279317
# 3    70  45.696322   92  113.461264  30.632114           42.538332
# 4    53  50.504232   92  104.461264  29.889149           42.172624
# ..  ...        ...  ...         ...        ...                 ...
# 76  322  36.900000   50  169.598513  16.132947           21.282008
# 77  238  19.197888  115  150.576579  37.923113           17.898973
# 78  263  34.000000   50  151.598513  15.769625           26.136381
# 79  295  19.833733  119  167.944460  39.423099           12.316518
# 80  236  12.101263  107  139.840817  34.948615           15.559404
#
#     Predictions_Model  Errors_Manual  Errors_Model          Y  Error_Squared  \
# 0           43.441935      10.258769     10.258747  53.700659     105.241882
# 1           42.388793       7.624633      7.624608  50.013377      58.134651
# 2           42.279341       7.734084      7.734060  50.013377      59.815679
# 3           42.538360       3.157991      3.157963  45.696294       9.972728
# 4           42.172648       8.331608      8.331584  50.504208      69.415289
# ..                ...            ...           ...        ...            ...
# 76          21.282096      15.617992     15.617904  36.899912     243.918926
# 77          17.899050       1.298915      1.298838  19.197810       1.686979
# 78          26.136453       7.863619      7.863547  33.999928      61.835369
# 79          12.316612       7.517215      7.517122  19.833640      56.507118
# 80          15.559481      -3.458142     -3.458218  12.101187      11.959270
#
#       LOG_HP    SQRT_HP
# 0   3.891820   7.000000
# 1   4.007333   7.416198
# 2   4.007333   7.416198
# 3   4.248495   8.366600
# 4   3.970292   7.280110
# ..       ...        ...
# 76  5.774552  17.944358
# 77  5.472271  15.427249
# 78  5.572154  16.217275
# 79  5.686975  17.175564
# 80  5.463832  15.362291
#
# [81 rows x 13 columns]

# %%
#Apply square root transformation on HP column and build model, check error
model=smf.ols('MPG~SQRT_HP+VOL',data = cars).fit()
print(model.pvalues)
model.mse_resid
# Out:
# Intercept    1.403770e-44
# SQRT_HP      6.147101e-24
# VOL          1.064574e-12
# dtype: float64
# 16.573611133979878

# %%
#Apply log transformation on HP column and build model, check error
cars['LOG_HP']=np.log(cars['HP'])
model=smf.ols('MPG~LOG_HP+VOL',data = cars).fit()
print(model.pvalues)
print(model.params)
model.mse_resid
# Out:
# Intercept    1.786377e-42
# LOG_HP       2.442973e-28
# VOL          9.529125e-13
# dtype: float64
# Intercept    128.290666
# LOG_HP       -16.800046
# VOL           -0.155593
# dtype: float64
# 12.794161086539388

# %%
#Apply square transformation on HP column and build model, check error
cars['SQ_HP']=np.square(cars['HP'])
model=smf.ols('MPG~SQ_HP+VOL',data = cars).fit()
print(model.pvalues)
model.mse_resid
# Out:
# Intercept    3.206299e-34
# SQ_HP        2.586373e-13
# VOL          5.043293e-12
# dtype: float64
# 30.887458973193823

# %%
#Apply cube root transformation on HP column and build model, check error
cars['CBRT_HP']=(cars['HP'])**(1/3)
model=smf.ols('MPG~CBRT_HP+VOL',data = cars).fit()
print(model.pvalues)
model.mse_resid
# Out:
# Intercept    1.174791e-43
# CBRT_HP      1.891122e-25
# VOL          9.616116e-13
# dtype: float64
# 15.164049754289145

# %%
list(np.where(model.resid>10))
# Out:
# [array([ 0, 76])]

# %%
sns.boxplot(model.resid)
# Out:
# <Axes: >

# %%
sns.histplot(cars["Errors_Model"])
# Out:
# <Axes: xlabel='Errors_Model', ylabel='Count'>

# %%
sns.distplot(cars['Errors_Model'])

# %% [markdown]
# ## Residual Plot for Homoscedasticity

# %%
def get_standardized_values(vals):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
get_standardized_values(model.resid).mean()

# %% [markdown]
# ## Residual Vs Regressors

# %% [markdown]
# fig = plt.figure(figsize=(15,8))
# fig = sm.graphics.plot_regress_exog(model, "VOL", fig=fig)
# plt.show()

# %% [markdown]
# import statsmodels.api as sm
# fig = plt.figure(figsize=(15,8))
# fig = sm.graphics.plot_regress_exog(model, "SP", fig=fig)
# plt.show()

# %% [markdown]
# fig = plt.figure(figsize=(15,8))
# fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
# plt.show()

# %% [markdown]
# fig = plt.figure(figsize=(15,8))
# fig = sm.graphics.plot_regress_exog(model, "WT", fig=fig)
# plt.show()

# %%
cars

# %%
#HP
#VOL
#SP
#WT
#Predicted
#Errors

plt.scatter(get_standardized_values(cars['VOL']),
            get_standardized_values(cars['Errors_Model']))

plt.title('Residual Plot')
plt.xlabel('Standardized Independent Data values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Transformations on Independent Variables
#
# 1. Log Transformation
# 2. Square Transformation
# 3. Square Root Transformation
# 4. Cube Transformation
# 5. Cube Root Transformation
# 6. Exponential Transformation

# %%
cars['SQRT_HP']=np.sqrt(cars['HP'])
cars

# %%
#Build model
#import statsmodels.formula.api as smf
model = smf.ols('MPG~WT+VOL+SP+SQRT_HP',data=cars).fit()

# %% [markdown]
# # Model Deletion Diagnostics

# %% [markdown]
# ## Detecting Influencers/Outliers

# %% [markdown]
# ## Cook’s Distance

# %%
cars.shape

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
c

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(cars)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))

# %% [markdown]
# ## High Influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
cars.shape

# %%
#k= number of variables (columns)
#n= number of observations (rows)
k = 4
n = 81
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff

# %% [markdown]
# #### From the above plot, it is evident that data point 70 and 76 are the influencers

# %%
cars[cars.index.isin([70, 76])]

# %%
#See the differences in HP and other variable values
cars.head()

# %% [markdown]
# # Improving the model

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
car1=cars.drop(cars.index[76],axis=0).reset_index()

# %%
car1.shape

# %%
#Drop the original index
car1=car1.drop(['index'],axis=1)

# %%
car1

# %% [markdown]
# # Build Model

# %%
#Exclude variable "WT" and generate R-Squared and AIC values
final_ml_V= smf.ols('MPG~VOL+SP+HP',data = car1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)

# %%
((final_ml_V.resid)**2).mean()

# %%
#Exclude variable "VOL" and generate R-Squared and AIC values
final_ml_W= smf.ols('MPG~WT+SP+HP',data = car1).fit()

# %%
(final_ml_W.rsquared,final_ml_W.aic)

# %%
((final_ml_W.resid)**2).mean()

# %% [markdown]
# ##### Comparing above R-Square and AIC values, model 'final_ml_V' has high R- square and low AIC value hence include variable 'VOL' so that multi collinearity problem would be resolved.

# %% [markdown]
# # Cook’s Distance

# %%
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(car1)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_V),np.max(c_V))

# %%
#Drop 76 and 77 observations
car2=car1.drop(car1.index[[76,77]],axis=0)

# %%
car2

# %%
#Reset the index and re arrange the row values
car3=car2.reset_index()

# %%
car4=car3.drop(['index'],axis=1)

# %%
car4

# %%
#Build the model on the new data
final_ml_V= smf.ols('MPG~VOL+SP+HP',data = car4).fit()

# %%
#Again check for influencers
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(car4)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_V),np.max(c_V))

# %%
#k= number of variables (columns)
#n= number of observations (rows)
k = 3
n = 79
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff

# %% [markdown]
# #### Since the value is <1 , we can stop the diagnostic process and finalize the model

# %%
#Check the accuracy of the mode
final_ml_V= smf.ols('MPG~VOL+SP+HP',data = car4).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)

# %% [markdown]
# ## Predicting for new data

# %%
#New data for prediction
new_data=pd.DataFrame({'HP':40,"VOL":95,"SP":102,"WT":35},index=[1])

# %%
new_data

# %%
final_ml_V.predict(new_data)

# %%
#final_ml_V.predict(cars_new.iloc[0:5,])

# %%
#pred_y = final_ml_V.predict(cars_new)

# %%
#pred_y

# %% [markdown]
# ### On the Toyota cars Data Set given to you, please run a multiple linear regression, & find the following:
#
# - Find the most significant
# - Independent variables that are
# - The correlation between fitted values & residuals
# - Whether the residuals follow a normal distribution or not
# - Also the VIF values for all independent variables
